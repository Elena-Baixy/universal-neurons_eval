# %%
import os
os.chdir('/net/scratch2/smallyan/universal-neurons_eval')
print(f"Working directory: {os.getcwd()}")
# Out:
# Working directory: /net/scratch2/smallyan/universal-neurons_eval

# %%
# Core imports
import torch
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import percentileofscore

device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f"Device: {device}")

torch.set_grad_enabled(False)

# Load the model
from transformer_lens import HookedTransformer
model_name = 'stanford-gpt2-small-a'
model = HookedTransformer.from_pretrained(model_name, device=device)
print(f"Loaded model with {model.cfg.n_layers} layers, d_mlp={model.cfg.d_mlp}")
# Out:
# Device: cuda

# %%
# Check model loaded correctly
print(f"Model type: {type(model)}")
print(f"Layers: {model.cfg.n_layers}")
print(f"d_mlp: {model.cfg.d_mlp}")
print(f"d_model: {model.cfg.d_model}")

# %%
# Something is suppressing output - let me check with an explicit result
result = {
    'n_layers': model.cfg.n_layers,
    'd_mlp': model.cfg.d_mlp,
    'd_model': model.cfg.d_model
}
result

# %%
import sys
sys.stdout.write(f"Layers: {model.cfg.n_layers}\n")
sys.stdout.flush()

# %%
# Let me just store values and work with them
n_layers = model.cfg.n_layers
d_mlp = model.cfg.d_mlp
d_model = model.cfg.d_model

# Test with pandas (which showed output before)
pd.DataFrame({'layers': [n_layers], 'd_mlp': [d_mlp], 'd_model': [d_model]})
